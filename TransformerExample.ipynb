# %%
import yfinance as yf
from yahoofinancials import YahooFinancials
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from keras.layers import Flatten
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler
from sklearn import metrics
from sklearn.metrics import mean_squared_error
import sqlite3
import pandas as pd
import math
import matplotlib.pyplot as plt

from datetime import datetime

#For reproducability
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

# %%
# Some functions to help out with
def plot_predictions(test,predicted,symbol):
    plt.plot(test, color='red',label=f'Real {symbol} Stock Price')
    plt.plot(predicted, color='blue',label=f'Predicted {symbol} Stock Price')
    plt.title(f'{symbol} Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel(f'{symbol} Stock Price')
    plt.legend()
    plt.show()

def plot_return_predictions(test,predicted,symbol):
    plt.plot(test, color='red',label=f'Real {symbol} Stock Price Returns')
    plt.plot(predicted, color='blue',label=f'Predicted {symbol} Stock Price Return')
    plt.title(f'{symbol} Stock Return Prediction')
    plt.xlabel('Time')
    plt.ylabel(f'{symbol} Stock Price Returns')
    plt.legend()
    plt.show()
    
def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

def get_ticker_data(ticker: str, param_start_date, param_end_date) -> dict:
    raw_data = YahooFinancials(ticker)
    return raw_data.get_historical_price_data(param_start_date, param_end_date, "daily").copy()

def fetch_ticker_data(ticker: str, start_date, end_date) -> pd.DataFrame:
    date_range = pd.bdate_range(start=start_date, end=end_date)
    values = pd.DataFrame({'Date': date_range})
    values['Date'] = pd.to_datetime(values['Date'])
    raw_data = get_ticker_data(ticker, start_date, end_date)
    return pd.DataFrame(raw_data[ticker]["prices"])[['date', 'open', 'high', 'low', 'adjclose', 'volume']]

def shift(xs, n):
    e = np.empty_like(xs)
    if n >= 0:
        e[:n] = np.nan
        e[n:] = xs[:-n]
    else:
        e[n:] = np.nan
        e[:n] = xs[-n:]
    return e

# %%
companyName = 'AMZN'
start_date = '2020-04-05'
end_date = '2023-04-05'
stock = fetch_ticker_data(companyName, start_date, end_date)

# %%
stock.columns = ['DateTime', 'Open', 'High', 'Low', 'Close', 'Volume']
stock['DateTime'] = stock['DateTime'].apply(lambda x: datetime.fromtimestamp(x))
stock = stock.fillna(method="ffill", axis=0)
stock = stock.fillna(method="bfill", axis=0)
stock = stock.set_index('DateTime')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7748\792272929.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stock = stock.fillna(method="ffill", axis=0)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_7748\792272929.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   stock = stock.fillna(method="bfill", axis=0)

# %%
stock.head()
# Out:
#                            Open        High         Low       Close     Volume
# DateTime
# 2020-04-06 20:30:00   96.800003   99.926003   96.500999   99.879501  115464000
# 2020-04-07 20:30:00  100.855499  101.786003   99.880997  100.580002  102280000
# 2020-04-08 20:30:00  101.050003  102.199997  100.557503  102.150002   79546000
# 2020-04-09 20:30:00  102.214996  102.650002  100.883003  102.138000   92930000
# 2020-04-13 20:30:00  102.000000  109.000000  101.900002  108.443497  134334000

# %%
stock['Symbol'] = companyName
stock.tail()
#save a copy for later testing
original_stock = stock
original_symbol = companyName

stock['Close'].tail()
# Out:
# DateTime
# 2023-03-29 20:30:00    100.250000
# 2023-03-30 20:30:00    102.000000
# 2023-03-31 20:30:00    103.290001
# 2023-04-03 20:30:00    102.410004
# 2023-04-04 20:30:00    103.949997
# Name: Close, dtype: float64

# %%
training_set = stock.iloc[:int(len(stock)*0.9),3:4].values 
test_set = stock.iloc[int(len(stock)*0.9):,3:4].values

test_set_return = stock.iloc[int(len(stock)*0.9):,3:4].pct_change().values
#log_return_test = np.log(test_set_return)

print(training_set.shape)
print(test_set.shape)
# Out:
# (679, 1)
# (76, 1)

# %%
stock['Close'].iloc[:int(len(stock)*0.9)].plot(figsize=(16,4),legend=True)
stock['Close'].iloc[int(len(stock)*0.9):].plot(figsize=(16,4),legend=True)
plt.legend([f'Training set',f'Test set'])
plt.title(f'{companyName} stock price')
plt.show()

# %%
# Scaling the training set - I've tried it without scaling and results are very poor.
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
timesteps = 8
# First, we create data sets where each sample has with 8 timesteps and 1 output
# So for each element of training set, we have 8 previous training set elements 
x_train = []
y_train = []
for i in range(timesteps,training_set.shape[0]):
    x_train.append(training_set_scaled[i-timesteps:i,0])
    y_train.append(training_set_scaled[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

print(x_train[0], y_train[0])
print(x_train[1], y_train[1])
# Out:
# [0.13680607 0.14378105 0.15941375 0.15929426 0.22207893 0.27905867
#  0.29118649 0.34122604] 0.32470217552519354
# [0.14378105 0.15941375 0.15929426 0.22207893 0.27905867 0.29118649
#  0.34122604 0.32470218] 0.33396725188029497

# %%
print(x_train.shape, y_train.shape)
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
print(x_train.shape, y_train.shape)
# Out:
# (671, 8) (671,)
# (671, 8, 1) (671,)

# %%
print(x_train.shape, y_train.shape)
# Interestingly - randomly arranging the samples works well, since we are using validation_split = 0.2, (rather then validation_data = )
# It is worth looking into whether using a K-fold would work better - if so would not use random permutation.
idx = np.random.permutation(len(x_train))
x_train = x_train[idx]
y_train = y_train[idx]
# Out:
# (671, 8, 1) (671,)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    
    # Normalization and Attention
    # "EMBEDDING LAYER"
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    
    # "ATTENTION LAYER"
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs
    
    # FEED FORWARD Part - you can stick anything here or just delete the whole section - it will still work. 
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation = "relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
#test
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    
    # Normalization and Attention
    # "EMBEDDING LAYER"
    #x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    
    # "ATTENTION LAYER"
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs
    
    # FEED FORWARD Part
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation = "relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    
    for _ in range(num_transformer_blocks):  # This is what stacks our transformer blocks
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="elu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1, activation="linear")(x) #this is a pass-through
    return keras.Model(inputs, outputs)

# %%
#test
def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    
    for _ in range(num_transformer_blocks):  # This is what stacks our transformer blocks
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_last")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1, activation="linear")(x) #this is a pass-through
    return keras.Model(inputs, outputs)

# %%
def lr_scheduler(epoch, lr, warmup_epochs=30, decay_epochs=100, initial_lr=1e-6, base_lr=1e-3, min_lr=5e-5):
    if epoch <= warmup_epochs:
        pct = epoch / warmup_epochs
        return ((base_lr - initial_lr) * pct) + initial_lr

    if epoch > warmup_epochs and epoch < warmup_epochs+decay_epochs:
        pct = 1 - ((epoch - warmup_epochs) / decay_epochs)
        return ((base_lr - min_lr) * pct) + min_lr

    return min_lr

# This learning rate scheduler is also from Mr. Theodoros Ntakouris' articla at https://towardsdatascience.com/the-time-series-transformer-2a521a0efad3
# I am definetely a fan.

# %%
callbacks = [
            keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
            keras.callbacks.LearningRateScheduler(lr_scheduler)
            ]

# %%
input_shape = x_train.shape[1:]
print(input_shape)
# Out:
# (8, 1)

# %%
model = build_model(
    input_shape,
    head_size=46, # Embedding size for attention
    num_heads=60, # Number of attention heads
    ff_dim=55, # Hidden layer size in feed forward network inside transformer
    num_transformer_blocks=5,
    mlp_units=[256],
    mlp_dropout=0.4,
    dropout=0.14,
)

model.compile(
    loss="mean_squared_error",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["mean_squared_error"],
)
#model.summary()


history = model.fit(
    x_train,
    y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=20,
    callbacks=callbacks,
)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 11s 151ms/step - loss: 0.0929 - mean_squared_error: 0.0929 - val_loss: 0.0564 - val_mean_squared_error: 0.0564 - lr: 1.0000e-06
# Epoch 2/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.0552 - mean_squared_error: 0.0552 - val_loss: 0.0082 - val_mean_squared_error: 0.0082 - lr: 3.4300e-05
# Epoch 3/100
# 27/27 [==============================] - 5s 181ms/step - loss: 0.0424 - mean_squared_error: 0.0424 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - lr: 6.7600e-05
# Epoch 4/100
# 27/27 [==============================] - 5s 176ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0090e-04
# Epoch 5/100
# 27/27 [==============================] - 5s 167ms/step - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.3420e-04
# Epoch 6/100
# 27/27 [==============================] - 4s 148ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 1.6750e-04
# Epoch 7/100
# 27/27 [==============================] - 5s 171ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - lr: 2.0080e-04
# Epoch 8/100
# 27/27 [==============================] - 5s 184ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 2.3410e-04
# Epoch 9/100
# 27/27 [==============================] - 4s 151ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 2.6740e-04
# Epoch 10/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - lr: 3.0070e-04
# Epoch 11/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.0192 - mean_squared_error: 0.0192 - val_loss: 0.0031 - val_mean_squared_error: 0.0031 - lr: 3.3400e-04
# Epoch 12/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0140 - mean_squared_error: 0.0140 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 3.6730e-04
# Epoch 13/100
# 27/27 [==============================] - 4s 138ms/step - loss: 0.0131 - mean_squared_error: 0.0131 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - lr: 4.0060e-04
# Epoch 14/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0030 - val_mean_squared_error: 0.0030 - lr: 4.3390e-04
# Epoch 15/100
# 27/27 [==============================] - 3s 121ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 4.6720e-04
# Epoch 16/100
# 27/27 [==============================] - 3s 127ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 5.0050e-04
# Epoch 17/100
# 27/27 [==============================] - 4s 131ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - lr: 5.3380e-04
# Epoch 18/100
# 27/27 [==============================] - 3s 129ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - lr: 5.6710e-04
# Epoch 19/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 6.0040e-04
# Epoch 20/100
# 27/27 [==============================] - 3s 128ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 6.3370e-04
# Epoch 21/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 6.6700e-04
# Epoch 22/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0023 - val_mean_squared_error: 0.0023 - lr: 7.0030e-04
# Epoch 23/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0024 - val_mean_squared_error: 0.0024 - lr: 7.3360e-04
# Epoch 24/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.0079 - mean_squared_error: 0.0079 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 7.6690e-04
# Epoch 25/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - lr: 8.0020e-04
# Epoch 26/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - lr: 8.3350e-04
# Epoch 27/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0026 - val_mean_squared_error: 0.0026 - lr: 8.6680e-04
# Epoch 28/100
# 27/27 [==============================] - 4s 153ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 9.0010e-04
# Epoch 29/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - lr: 9.3340e-04
# Epoch 30/100
# 27/27 [==============================] - 4s 151ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 9.6670e-04
# Epoch 31/100
# 27/27 [==============================] - 5s 178ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0010
# Epoch 32/100
# 27/27 [==============================] - 4s 152ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - lr: 9.9050e-04
# Epoch 33/100
# 27/27 [==============================] - 4s 157ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0028 - val_mean_squared_error: 0.0028 - lr: 9.8100e-04
# Epoch 34/100
# 27/27 [==============================] - 4s 145ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - lr: 9.7150e-04
# Epoch 35/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0027 - val_mean_squared_error: 0.0027 - lr: 9.6200e-04
# Epoch 36/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 9.5250e-04
# Epoch 37/100
# 27/27 [==============================] - 4s 134ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 9.4300e-04
# Epoch 38/100
# 27/27 [==============================] - 4s 134ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - lr: 9.3350e-04
# Epoch 39/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 9.2400e-04
# Epoch 40/100
# 27/27 [==============================] - 3s 130ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0020 - val_mean_squared_error: 0.0020 - lr: 9.1450e-04
# Epoch 41/100
# 27/27 [==============================] - 4s 132ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 9.0500e-04
# Epoch 42/100
# 27/27 [==============================] - 4s 132ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - lr: 8.9550e-04
# Epoch 43/100
# 27/27 [==============================] - 4s 132ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 8.8600e-04
# Epoch 44/100
# 27/27 [==============================] - 3s 128ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0022 - val_mean_squared_error: 0.0022 - lr: 8.7650e-04
# Epoch 45/100
# 27/27 [==============================] - 4s 136ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 8.6700e-04
# Epoch 46/100
# 27/27 [==============================] - 3s 127ms/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 8.5750e-04
# Epoch 47/100
# 27/27 [==============================] - 4s 138ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 8.4800e-04
# Epoch 48/100
# 27/27 [==============================] - 4s 132ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0025 - val_mean_squared_error: 0.0025 - lr: 8.3850e-04
# Epoch 49/100
# 27/27 [==============================] - 4s 133ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 8.2900e-04
# Epoch 50/100
# 27/27 [==============================] - 3s 126ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 8.1950e-04
# Epoch 51/100
# 27/27 [==============================] - 3s 123ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 8.1000e-04
# Epoch 52/100
# 27/27 [==============================] - 4s 132ms/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 8.0050e-04
# Epoch 53/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0021 - val_mean_squared_error: 0.0021 - lr: 7.9100e-04
# Epoch 54/100
# 27/27 [==============================] - 4s 152ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 7.8150e-04
# Epoch 55/100
# 27/27 [==============================] - 4s 146ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 7.7200e-04
# Epoch 56/100
# 27/27 [==============================] - 4s 135ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 7.6250e-04
# Epoch 57/100
# 27/27 [==============================] - 4s 149ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 7.5300e-04
# Epoch 58/100
# 27/27 [==============================] - 4s 156ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 7.4350e-04
# Epoch 59/100
# 27/27 [==============================] - 4s 137ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 7.3400e-04
# Epoch 60/100
# 27/27 [==============================] - 3s 128ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 7.2450e-04
# Epoch 61/100
# 27/27 [==============================] - 4s 131ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 7.1500e-04
# Epoch 62/100
# 27/27 [==============================] - 3s 130ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 7.0550e-04
# Epoch 63/100
# 27/27 [==============================] - 3s 129ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 6.9600e-04
# Epoch 64/100
# 27/27 [==============================] - 4s 133ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 6.8650e-04
# Epoch 65/100
# 27/27 [==============================] - 4s 133ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 6.7700e-04
# Epoch 66/100
# 27/27 [==============================] - 4s 133ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 6.6750e-04
# Epoch 67/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 6.5800e-04
# Epoch 68/100
# 27/27 [==============================] - 5s 169ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0019 - val_mean_squared_error: 0.0019 - lr: 6.4850e-04
# Epoch 69/100
# 27/27 [==============================] - 4s 162ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 6.3900e-04
# Epoch 70/100
# 27/27 [==============================] - 4s 149ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 6.2950e-04
# Epoch 71/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 6.2000e-04
# Epoch 72/100
# 27/27 [==============================] - 4s 148ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 6.1050e-04
# Epoch 73/100
# 27/27 [==============================] - 4s 145ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 6.0100e-04
# Epoch 74/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.9150e-04
# Epoch 75/100
# 27/27 [==============================] - 4s 137ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.8200e-04
# Epoch 76/100
# 27/27 [==============================] - 4s 144ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.7250e-04
# Epoch 77/100
# 27/27 [==============================] - 4s 147ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.6300e-04
# Epoch 78/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 0.0017 - val_mean_squared_error: 0.0017 - lr: 5.5350e-04
# Epoch 79/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.4400e-04
# Epoch 80/100
# 27/27 [==============================] - 4s 138ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.3450e-04
# Epoch 81/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 5.2500e-04
# Epoch 82/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.1550e-04
# Epoch 83/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 5.0600e-04
# Epoch 84/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.9650e-04
# Epoch 85/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.8700e-04
# Epoch 86/100
# 27/27 [==============================] - 4s 158ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.7750e-04
# Epoch 87/100
# 27/27 [==============================] - 4s 163ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 4.6800e-04
# Epoch 88/100
# 27/27 [==============================] - 4s 155ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 4.5850e-04
# Epoch 89/100
# 27/27 [==============================] - 4s 149ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.4900e-04
# Epoch 90/100
# 27/27 [==============================] - 4s 147ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.3950e-04
# Epoch 91/100
# 27/27 [==============================] - 4s 150ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.3000e-04
# Epoch 92/100
# 27/27 [==============================] - 4s 147ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.2050e-04
# Epoch 93/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 4.1100e-04
# Epoch 94/100
# 27/27 [==============================] - 4s 141ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 4.0150e-04
# Epoch 95/100
# 27/27 [==============================] - 4s 143ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 3.9200e-04
# Epoch 96/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 3.8250e-04
# Epoch 97/100
# 27/27 [==============================] - 4s 139ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 3.7300e-04
# Epoch 98/100
# 27/27 [==============================] - 4s 142ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0016 - val_mean_squared_error: 0.0016 - lr: 3.6350e-04
# Epoch 99/100
# 27/27 [==============================] - 4s 140ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0018 - val_mean_squared_error: 0.0018 - lr: 3.5400e-04
# Epoch 100/100
# 27/27 [==============================] - 4s 137ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0015 - val_mean_squared_error: 0.0015 - lr: 3.4450e-04

# %%
# First we have to frontload the test data before the inital values of our test_set

dataset_total = pd.concat((original_stock['Close'].iloc[:int(len(stock)*0.9)],original_stock['Close'].iloc[int(len(stock)*0.9):]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - timesteps:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.fit_transform(inputs)

X_test = []
for i in range(timesteps,test_set.shape[0] + timesteps):
    X_test.append(inputs[i-timesteps:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


print(test_set[-3],test_set[-2], test_set[-1])
shifted_test_set = shift(test_set, 1) #The shift function is defined early in the notebook
print(shifted_test_set[-3],shifted_test_set[-2], shifted_test_set[-1])

print(predicted_stock_price[-1])
prediction_error = test_set - predicted_stock_price # This is the error on the same day
#Before we can calculate the predicted return we have to shift the test_set to the day before so we use the shifted_test_set
predicted_return = (shifted_test_set - predicted_stock_price) / shifted_test_set

plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()

plot_predictions(test_set,predicted_stock_price,original_symbol)
return_rmse(test_set,predicted_stock_price)

plot_return_predictions(test_set_return,predicted_return,original_symbol)
print('Stock price return:')
return_rmse(test_set_return[1:], predicted_return[1:])
# Out:
# 3/3 [==============================] - 1s 70ms/step
# [103.29000092] [102.41000366] [103.94999695]
# [102.] [103.29000092] [102.41000366]
# [102.66222]
# The root mean squared error is 2.34293916607489.
# Stock price return:
# The root mean squared error is 0.025040791850988186.
# 0.025040791850988186

# %%
# First we have to frontload the test data before the inital values of our test_set

dataset_total = pd.concat((original_stock['Close'].iloc[:int(len(stock)*0.9)],original_stock['Close'].iloc[int(len(stock)*0.9):]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - timesteps:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.fit_transform(inputs)

X_test = []
for i in range(timesteps,test_set.shape[0] + timesteps):
    X_test.append(inputs[i-timesteps:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


print(test_set[-3],test_set[-2], test_set[-1])
shifted_test_set = shift(test_set, 1) #The shift function is defined early in the notebook
print(shifted_test_set[-3],shifted_test_set[-2], shifted_test_set[-1])

print(predicted_stock_price[-1])
prediction_error = test_set - predicted_stock_price # This is the error on the same day
#Before we can calculate the predicted return we have to shift the test_set to the day before so we use the shifted_test_set
predicted_return = (shifted_test_set - predicted_stock_price) / shifted_test_set

plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()

plot_predictions(test_set,predicted_stock_price,original_symbol)
return_rmse(test_set,predicted_stock_price)

plot_return_predictions(test_set_return,predicted_return,original_symbol)
print('Stock price return:')
return_rmse(test_set_return[1:], predicted_return[1:])
# Out:
# 3/3 [==============================] - 0s 44ms/step
# [103.29000092] [102.41000366] [103.94999695]
# [102.] [103.29000092] [102.41000366]
# [101.83383]
# The root mean squared error is 2.670184771829409.
# Stock price return:
# The root mean squared error is 0.02899615949819712.
# 0.02899615949819712

# %%
# geting the score and error
print(f'Mean Absolute Error: {metrics.mean_absolute_error(test_set, predicted_stock_price)}')
print(f'Mean Squared Error: {metrics.mean_squared_error(test_set, predicted_stock_price)}')
print(f'Root Mean Squared Error: {np.sqrt(metrics.mean_squared_error(test_set, predicted_stock_price))}')
print(f'R2_Score: {metrics.r2_score(test_set, predicted_stock_price)}')
print(f'Mean Absolute Percentage Error: {metrics.mean_absolute_percentage_error(test_set, predicted_stock_price)}')
# Out:
# Mean Absolute Error: 1.821447673596834
# Mean Squared Error: 5.4893639359277016
# Root Mean Squared Error: 2.34293916607489
# R2_Score: 0.8626880945062005
# Mean Absolute Percentage Error: 0.019018581455181954

# %%
# geting the score and error
print(f'Mean Absolute Error: {metrics.mean_absolute_error(test_set, predicted_stock_price)}')
print(f'Mean Squared Error: {metrics.mean_squared_error(test_set, predicted_stock_price)}')
print(f'Root Mean Squared Error: {np.sqrt(metrics.mean_squared_error(test_set, predicted_stock_price))}')
print(f'R2_Score: {metrics.r2_score(test_set, predicted_stock_price)}')
print(f'Mean Absolute Percentage Error: {metrics.mean_absolute_percentage_error(test_set, predicted_stock_price)}')
# Out:
# Mean Absolute Error: 2.0685284263209294
# Mean Squared Error: 7.129886715709673
# Root Mean Squared Error: 2.670184771829409
# R2_Score: 0.8216517719873917
# Mean Absolute Percentage Error: 0.02153766935052496

# %%
# Test for time_step 20

dataset_total = pd.concat((original_stock['Close'].iloc[:int(len(stock)*0.9)],original_stock['Close'].iloc[int(len(stock)*0.9):]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - timesteps:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.fit_transform(inputs)

X_test = []
for i in range(timesteps,test_set.shape[0] + timesteps):
    X_test.append(inputs[i-timesteps:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)


print(test_set[-3],test_set[-2], test_set[-1])
shifted_test_set = shift(test_set, 1) #The shift function is defined early in the notebook
print(shifted_test_set[-3],shifted_test_set[-2], shifted_test_set[-1])

print(predicted_stock_price[-1])
prediction_error = test_set - predicted_stock_price # This is the error on the same day
#Before we can calculate the predicted return we have to shift the test_set to the day before so we use the shifted_test_set
predicted_return = (shifted_test_set - predicted_stock_price) / shifted_test_set

plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss'], loc='upper left')
plt.show()

plot_predictions(test_set,predicted_stock_price,original_symbol)
return_rmse(test_set,predicted_stock_price)

plot_return_predictions(test_set_return,predicted_return,original_symbol)
return_rmse(test_set_return[1:], predicted_return[1:])
# Out:
# 3/3 [==============================] - 2s 182ms/step
# [103.29000092] [102.41000366] [103.94999695]
# [102.] [103.29000092] [102.41000366]
# [101.85428]
# The root mean squared error is 2.7384355859719056.
# The root mean squared error is 0.029315945374416955.
# 0.029315945374416955
